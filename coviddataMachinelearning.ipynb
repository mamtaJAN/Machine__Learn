# %%
import numpy as np
import pandas as pd

# %%
a = pd.read_csv('covid.csv')
a
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
a
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
a.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
a.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
a.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
top_left_corner_a=a.iloc[:4,:3]
top_left_corner_a
# Out:
#    age  gender  fever
# 0   60    Male  103.0
# 1   27    Male  100.0
# 2   42    Male  101.0
# 3   31  Female   98.0

# %%
a.loc[1:3,['gender','fever']]
# Out:
#    gender  fever
# 1    Male  100.0
# 2    Male  101.0
# 3  Female   98.0

# %%
s=a.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')]

# %%
p=a.dtypes
p
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
b=a.empty
b
# Out:
# False

# %%
i=a.ndim

# %%
t=a.shape

# %%
t
# Out:
# (100, 6)

# %%
a=a.copy()

# %%
p=a.sort_values(by='gender')
p
# Out:
#     age  gender  fever   cough       city has_covid
# 99   10  Female   98.0  Strong    Kolkata       Yes
# 85   16  Female  103.0    Mild  Bangalore       Yes
# 69   73  Female  103.0    Mild      Delhi        No
# 36   38  Female  101.0    Mild  Bangalore        No
# 84   69  Female   98.0  Strong     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 58   23    Male   98.0  Strong     Mumbai       Yes
# 63   10    Male  100.0    Mild  Bangalore        No
# 64   42    Male  104.0    Mild     Mumbai        No
# 67   65    Male   99.0    Mild  Bangalore        No
# 49   44    Male  104.0    Mild     Mumbai        No
#
# [100 rows x 6 columns]

# %%
r=a.sort_index()
r
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
a['age']=a['age'].astype(int)
a
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
t
a['age']=a['age'].add(4)
a
# Out:
#     age  gender  fever   cough       city has_covid
# 0    64    Male  103.0    Mild    Kolkata        No
# 1    31    Male  100.0    Mild      Delhi       Yes
# 2    46    Male  101.0    Mild      Delhi        No
# 3    35  Female   98.0    Mild    Kolkata        No
# 4    69  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   16  Female  104.0    Mild  Bangalore        No
# 96   55  Female  101.0  Strong    Kolkata       Yes
# 97   24  Female  101.0    Mild  Bangalore        No
# 98    9  Female   98.0  Strong     Mumbai        No
# 99   14  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
s=a.count()
s
# Out:
# age          100
# gender       100
# fever         90
# cough        100
# city         100
# has_covid    100
# dtype: int64

# %%
p=a.max()
p
# Out:
# age              88
# gender         Male
# fever         104.0
# cough        Strong
# city         Mumbai
# has_covid       Yes
# dtype: object

# %%
q=a.min()
q
# Out:
# age                  9
# gender          Female
# fever             98.0
# cough             Mild
# city         Bangalore
# has_covid           No
# dtype: object

# %%
s=a.sum()
s
# Out:
# age                                                       4822
# gender       MaleMaleMaleFemaleFemaleFemaleMaleFemaleFemale...
# fever                                                   9076.0
# cough        MildMildMildMildMildMildStrongStrongStrongMild...
# city         KolkataDelhiDelhiKolkataMumbaiBangaloreBangalo...
# has_covid    NoYesNoNoNoYesNoYesNoNoNoYesNoYesNoYesYesNoYes...
# dtype: object

# %%
g=a.filter(items=['gender','age'])
g
# Out:
#     gender  age
# 0     Male   64
# 1     Male   31
# 2     Male   46
# 3   Female   35
# 4   Female   69
# ..     ...  ...
# 95  Female   16
# 96  Female   55
# 97  Female   24
# 98  Female    9
# 99  Female   14
#
# [100 rows x 2 columns]

# %%
a[['age','fever']]
# Out:
#     age  fever
# 0    64  103.0
# 1    31  100.0
# 2    46  101.0
# 3    35   98.0
# 4    69  101.0
# ..  ...    ...
# 95   16  104.0
# 96   55  101.0
# 97   24  101.0
# 98    9   98.0
# 99   14   98.0
#
# [100 rows x 2 columns]

# %%
s=a.filter(items=[5,6],axis=0)
s
# Out:
#    age  gender  fever   cough       city has_covid
# 5   88  Female    NaN    Mild  Bangalore       Yes
# 6   18    Male  101.0  Strong  Bangalore        No

# %%
s=a.to_dict()
s
# Out:
# {'age': {0: 64,
#   1: 31,
#   2: 46,
#   3: 35,
#   4: 69,
#   5: 88,
#   6: 18,
#   7: 24,
#   8: 23,
#   9: 68,
#   10: 79,
#   11: 69,
#   12: 29,
#   13: 68,
#   14: 55,
#   15: 74,
#   16: 73,
#   17: 44,
#   18: 68,
#   19: 46,
#   20: 16,
#   21: 77,
#   22: 75,
#   23: 84,
#   24: 17,
#   25: 27,
#   26: 23,
#   27: 37,
#   28: 20,
#   29: 38,
#   30: 19,
#   31: 87,
#   32: 38,
#   33: 30,
#   34: 78,
#   35: 86,
#   36: 42,
#   37: 59,
#   38: 53,
#   39: 54,
#   40: 53,
#   41: 86,
#   42: 31,
#   43: 26,
#   44: 24,
#   45: 76,
#   46: 23,
#   47: 22,
#   48: 70,
#   49: 48,
#   50: 23,
#   51: 15,
#   52: 51,
#   53: 87,
#   54: 64,
#   55: 85,
#   56: 75,
#   57: 53,
#   58: 27,
#   59: 10,
#   60: 28,
#   61: 85,
#   62: 60,
#   63: 14,
#   64: 46,
#   65: 73,
#   66: 55,
#   67: 69,
#   68: 58,
#   69: 77,
#   70: 72,
#   71: 79,
#   72: 87,
#   73: 38,
#   74: 38,
#   75: 9,
#   76: 84,
#   77: 12,
#   78: 15,
#   79: 52,
#   80: 18,
#   81: 69,
#   82: 28,
# ...

# %%
q=a.to_string()
q
# Out:
# '    age  gender  fever   cough       city has_covid\n0    64    Male  103.0    Mild    Kolkata        No\n1    31    Male  100.0    Mild      Delhi       Yes\n2    46    Male  101.0    Mild      Delhi        No\n3    35  Female   98.0    Mild    Kolkata        No\n4    69  Female  101.0    Mild     Mumbai        No\n5    88  Female    NaN    Mild  Bangalore       Yes\n6    18    Male  101.0  Strong  Bangalore        No\n7    24  Female    NaN  Strong     Mumbai       Yes\n8    23  Female  100.0  Strong  Bangalore        No\n9    68  Female  101.0    Mild      Delhi        No\n10   79  Female    NaN    Mild      Delhi        No\n11   69  Female   98.0    Mild     Mumbai       Yes\n12   29  Female   99.0  Strong    Kolkata        No\n13   68    Male  102.0    Mild  Bangalore       Yes\n14   55    Male  104.0    Mild  Bangalore        No\n15   74    Male  103.0  Strong    Kolkata       Yes\n16   73  Female  103.0    Mild    Kolkata       Yes\n17   44  Female   98.0  Strong      Delhi  
# ...

# %%
idx=a.columns
idx
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
label=a.columns.tolist()
label
# Out:
# ['age', 'gender', 'fever', 'cough', 'city', 'has_covid']

# %%
p=a.columns.values
p
# Out:
# array(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'],
#       dtype=object)
