# %% [markdown]
# #DATA ==> Input (x),target(y)
# # Input(x)===>x_train,x_test
# #Target(y)===> y_train,y_test
# # ML WorkFlow==>
# #Data Gathering ===> Data cleaning and preprocessing ====> M Models(x_train)

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("placement.csv")
df.head(3)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1

# %%
x=df.drop(columns=['placed'],axis=1)## input colums
y=df['placed'] ## Target column

# %%
# (100,2)+ (100,1)=(100,3)
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.0 MB 3.2 MB/s eta 0:00:04
#     --------------------------------------- 0.1/11.0 MB 1.7 MB/s eta 0:00:07
#     --------------------------------------- 0.2/11.0 MB 1.2 MB/s eta 0:00:09
#     --------------------------------------- 0.2/11.0 MB 1.2 MB/s eta 0:00:09
#     --------------------------------------- 0.2/11.0 MB 871.5 kB/s eta 0:00:13
#     --------------------------------------- 0.2/11.0 MB 737.3 kB/s eta 0:00:15
#     --------------------------------------- 0.3/11.0 MB 827.5 kB/s eta 0:00:13
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=30)

# %%
print("Total Data Shape:",df.shape)
print("Independent Data Shape(x)",x.shape)
print("x_train Data Shape(x_train):",x_train.shape)
print("x_test Data shape(x_test):",x_test.shape)
print("Dependent Data Shapes(y):",y.shape)
print("y_train Data Shapes(y_train):",y_train.shape)
print("y_test Data Shape(y_test):",y_test.shape)
# Out:
# Total Data Shape: (100, 3)
# Independent Data Shape(x) (100, 2)
# x_train Data Shape(x_train): (70, 2)
# x_test Data shape(x_test): (30, 2)
# Dependent Data Shapes(y): (100,)
# y_train Data Shapes(y_train): (70,)
# y_test Data Shape(y_test): (30,)

# %%
df=pd.read
